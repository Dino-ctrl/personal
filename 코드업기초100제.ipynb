# %%
#2020.12 코드업 기초 100제 
#1008
print("\u250C\u252C\u2510")
print("\u251C\u253C\u2524")
print("\u2514\u2534\u2518")

print('\u250C\u252C\u2510')
print('\u251C\u253C\u2524')
print('\u2514\u2534\u2518')

#1010
a=int(input())
print(a)

#1011
a=str(input())
print(a)

#1012
a=float(input())
print("%6f" %a)

#1013
n1, n2 =input().split()
print(n1, n2)

#1014
n1, n2=input().split()
print(n2, n1)

#1015 (반올림할때 . 찍어주기)
a=float(input())
print("%.2f" %a)

#1017
a=int(input())
print(a, a, a)

#1018
h,m = input().split(':')
print(int(h), int(m), sep=':')

#1019
y,m,d=input().split('.')
print('%04d' %int(y) +'.'+ '%02d' %int(m) +'.'+ '%02d' %int(d))

#1020
front, back = input().split('-')
print(front+back)

#1021
a=str(input())
print(a)

#1022
a=str(input())
print(a)

#1023
a, b =input().split('.')
print("%d" % int(a))
print("%d" % float(b))


#1024
a=input()
for i in a:
    print("'" + i + "'")

#12/08
#1025
a, b, c, d, e=map(int, input())
print('[%d0000]\n[%d000]\n[%d00]\n[%d0]\n[%d]' %(a, b, c, d, e))

#1026
h, m, s=map(int, input().split(':'))
print(m)

#1027
y, m, d=map(int, input().split('.'))
print('%02d' %d+'-'+'%02d'%m+'-'+'%04d'%y)

#더 간단한 풀이
y, m, d = map(int, input().split('.'))
print(d + "-" + m +"-" +y)


#1028
a=input()
print(int(a))

#1029
a=float(input())
print('%.11f' %a)

#1030
a=input()
print(int(a))

#1031
a=int(input())
print('%o'%a)

#1032
a=input()
print('%x'%int(a))

#1033 #대문자는 출력을 대문자로 바꿔 주면됨
a=input()
print('%X'%int(a))


#1034 #8진수 입력법
a=int(input(),8)
print("%d"%a)

#1035
a=int(input(),16)
print('%o' %a)


#1036 #ord = 아스키 코드 입력받아서 숫자로 변환시켜줄대 사용함
a=input()
print(ord(a))

#1037 #아스키 코드 출력은 chr
a=int(input())
print(chr(a))

#1038
a, b=map(int, input().split())
print(a+b)

#1039
a, b=map(int, input().split())
print(a+b)

#1040
a=input()
print(-int(a))

#1041
a=ord(input())
print(chr(a+1))

#1042
a, b=map(int, input().split())
print(a//b)

#1043
a,b=map(int, input().split())
print(a%b)

#1044
a=int(input())
print(a+1)


#1045
a, b=map(int, input().split())
print(a+b)
print(a-b)
print(a*b)
print(a//b)
print(a%b)
print('%.2f' % (a/b))

#1046
a,b,c=map(int, input().split())
print(a+b+c)
print('%.1f' % ((a+b+c)/3))

#1047
a=int(input())
print(a*2)

or
a = int(input())
print(a<<1)
 
#1048
a, b=map(int, input().split())
print(a<<b)

#1049
a, b=map(int, input().split())
if a>b:
    print(1)
else: 
    print(0)

#1050
a, b=map(int, input().split())
if a==b:
    print(1)
else:
    print(0)


#1051
a,b=map(int, input().split())
if a<=b: 
    print(1)
else: 
    print(0)


#1052
a, b=map(int, input().split())
if a!=b:
    print(1)
else:
    print(0)


#1053
a=int(input())
if a==1:
    print(0)
else:
    print(1)

#1054
a, b=map(int, input().split())
if a==1 & b==1:
    print(1)
else:
    print(0)


#1055
a, b=map(float, input().split())
if a==1 or b==1:
    print(1)
else:
    print(0)


#1056
a, b=map(float, input().split())
if a!=b:
    print(1)
else:
    print(0)

#1057
a, b=map(float, input().split())
if a==b:
    print(1)
else:
    print(0)


#1058
a, b=map(float, input().split())
if a==0 and b==0:
    print(1)
else:
    print(0)


#1059
a=int(input())
print(~a)


#1060 #비트 연산자 
a, b=map(int, input().split())
print(a&b)


#1061
a, b=map(int, input().split())
print(a|b)


#1062
a, b=map(int, input().split())
print(a^b)

#1063
a, b=map(int, input().split())
if a>b:
    print(a)
else:
    print(b)


#1064
a, b, c=map(int, input().split())
m = a if a<b else b
print(m if m < c else c)


#1065
a, b, c=map(int, input().split())
if a % 2 ==0:
print(a)
if b % 2 ==0:
print(b)
if c % 2 ==0:
print(c)


#1066
a, b, c=map(int, input().split())
if a%2==0:
    print("even")
else:
    print("odd")

if b%2==0:
    print("even")
else:
    print("odd")

if c%2==0:
    print("even")
else:
    print("odd")

#1067
a=int(input())
if a<abs(a):
    print("minus")
else:
    print("plus")
if a % 2==0:
    print("even")
else:
    print("odd")


#1068 #python은 elif
a=int(input())
if a>=90:
    print("A")
elif a>=70:
    print("B")
elif a>=40:
    print("C")
else:
    print("D")


#1069
a=input()
if a=="A":
    print("best!!!")
elif a=="B":
    print("good!!")
elif a=="C":
    print("run!")
elif a=="D":
    print("slowly~")
else:
    print("what?")


#1070
a=int(input())
if a in(12, 1, 2):
print("winter")
elif a in(3, 4, 5):
print("spring")
elif  a in(6, 7, 8):
print("summer")
else:
print("fall")

#12/10
1071
a=input().split()
num =list(map(int,a))
for i in num:
    if i==0:
        break
    else:
        print(i)
        
        


#1072
n=int(input())
num=list(map(int, input().split()))
for i in num:
    print(i)


#1073
a=input().split()
num =list(map(int,a))
for i in num:
    if i==0:
        break
    else:
        print(i)


#1074
a=int(input())
for i in range(a):
print(a-i)


#1075
a=int(input())
for i in range(a):
print(a-i-1)


#1076  #ord = 문자를 102 아스키 코드로 바꿔줌 
f=ord(input())
a=97
while(f+1 > a):
    print(chr(a), sep="")
    a +=1 





#2021 2/15
#1077
n=int(input())

a=0
while n+1 != a:
    print(a)
    a+=1


#1078
n=int(input())
a=0
for i in range(1, n+1):
    if i % 2 ==0:
        a+=i
print(a)


#1079
a=input().split()
for i in a:
    print(i)
    if i=='q':
        break


#1080
a = int(input())
n=0
for i in range(a+1):
    n+=i
    if n>=a:
        print(i)
        break

#1081
a, b = map(int, input().split())
for i in range(1, a+1):
    for j in range(1, b+1):
        print(i, j)


#1082
a=str(input())

b=int(a, 16)
for i in range(1, 16):
    print('%s*%X=%X' % (a, i, b*i))


#1083
a=int(input())

for i in range(1, a+1):
if i % 3 !=0:
print(i, end=' ')
else:
print('X', end=' ')
# Out:
#   File "<ipython-input-1-ad7ca7c66695>", line 177
#     or
#     ^
# SyntaxError: invalid syntax
